# %%
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

import numpy as np

import pandas as pd

import pickle

import ingest

from sklearn.decomposition import TruncatedSVD

import matplotlib.pyplot as plt

from scipy.sparse import coo_matrix, hstack
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import normalize


from joblib import parallel_backend

import xgboost as xgb

import math

import itertools
from tqdm import tqdm

from scipy import sparse

# %%
## input is a list of features from the nested dictionary that Taylor's code will spit out. The keys in this dictionary are associated with sparse matrices ##
## If the length of the input is greater than one, the function will do an hstack with those feats and their respective sparse matrices. If not the code    ##
## will simply take the input and run it through the SVD model to return a tuple with the matrix representation of the desired feature set along with the   ##
## Summation of the explained variation ratio array, along with a graph to show how the components are interacting to make-up total explainability. If the  ##
## If the hstack needs to be performed, then it will happen before the SVD model runs and render the above just the same.                                   ##



def PCA_encoder(f_dict,input,x):
    masterfeatdict = f_dict
    if len(input) == 4:
        a = masterfeatdict[input[0]]
        b = masterfeatdict[input[1]]
        c = masterfeatdict[input[2]]
        d = masterfeatdict[input[3]]
        stack = hstack([a,b,c,d])
    elif len(input) == 3:
        a = masterfeatdict[input[0]]
        b = masterfeatdict[input[1]]
        c = masterfeatdict[input[2]]
        stack = hstack([a,b,c])
    elif len(input) == 2:
        a = masterfeatdict[input[0]]
        b = masterfeatdict[input[1]]
        stack = hstack([a,b])
    else:
        stack = masterfeatdict[input[0]]


    encodedfeats = TruncatedSVD(n_components=x)

    encodedfeats_fit = encodedfeats.fit_transform(stack)

    exp_var_pca  = encodedfeats.explained_variance_ratio_

    cum_sum_eigenvalues = np.cumsum(exp_var_pca)
#   
    
# Create the visualization plot
#
    plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center', label='Individual explained variance')
    plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
    
    return encodedfeats_fit,exp_var_pca.sum()

# %%
outpatient = ingest.get_cache_data("Outpatient", "Outpatient.pkl")
outpatient.dropna(subset=['CLM_PMT_AMT'], inplace=True)
outpatient = outpatient[['CLM_PMT_AMT']]
# Out:
# INFO:root:Reading local cache file Outpatient.pkl

# %%
with open('feature_vectors_dictionary-truncated.txt', 'rb') as handle:
    feature_dictionary = pickle.load(handle)

for met_set in feature_dictionary.keys():
    print(met_set)
    feature_dictionary[met_set] = normalize(sparse.csr_matrix(feature_dictionary[met_set]))
    print(np.shape(feature_dictionary[met_set]))


feature_dictionary['PCA-HCPCS_CD'], wow1 = PCA_encoder(feature_dictionary, ['HCPCS_CD'],1000)
print(wow1)

feature_dictionary['PCA-DGNS_CD'], wow2 = PCA_encoder(feature_dictionary, ['DGNS_CD'],2500)
print(wow2)

feature_dictionary['PCA-HCPCS-DGNS_CD'], wow3 = PCA_encoder(feature_dictionary, ['HCPCS_CD', 'DGNS_CD'],3000)
print(wow3)
# Out:
# BIRTH_DATE
# (790790, 1)
# SEX
# (790790, 1)
# State
# (790790, 52)
# County
# (790790, 306)
# clm_dates
# (790790, 1)
# provider
# (790790, 4317)
# provider_count
# (790790, 1)
# DGNS_CD
# (790790, 11702)
# DGNS_CD_count
# (790790, 1)
# PRDCR_CD
# (790790, 288)
# PRDCR_CD_count
# (790790, 1)
# HCPCS_CD
# (790790, 5619)
# HCPCS_CD_count
# (790790, 1)
# 0.9425266015333092
# 0.8099198355832538
# 0.8245701866931845

# %%
def run_model(X, y, model, grid, feature_names):

       ### Runs the model and returns MSE and R2 values and corresponding data as a dataframe

       ### Takes in four arugments
       ### X is the features to that model will be trained on as a sparse matrix
       ### y is the scalar that is to be predicted as a list
       ### model is the regression model as a model object
       ### grid is a dictionary of model hyperparameters

       ### returns a dataframe of results from the grid search

       scoring = {'mean_squared_error': make_scorer(mean_squared_error), 'r2_score': make_scorer(r2_score)}
       with parallel_backend('threading', n_jobs=2):
              grid_model = GridSearchCV(model, grid, scoring=scoring, refit=False, return_train_score=True, error_score="raise").fit(X.todense(), y)
       
       print(grid_model.cv_results_)

       df=pd.DataFrame.from_dict(grid_model.cv_results_)
       
       return df

# %%
def iterate_feature_sets(model, feature_dict, grid, feature_sets):

    ### Creates and runs the specified model with each comboniation of features sets from 1 to k length features and stores the results of the models into a dictionary

    ### Takes in four arguments
    ### model is the regression model as a model object
    ### feature_dict is the dictionary of feature sets
    ### grid is a dictionary of model hyperparameters
    ### feature_sets dicates how what feature sets will be returned, a list of list of strings corresponding to the keys in the dictionary
    ### (continued) all would return all combinations for 1 through k, where  k is the number of keys in feature_dict

    ### returns a dictionary of results

    results = {}

    for feature_list in feature_sets:
        if feature_list == 'all':

            for n_met in tqdm(range(len(feature_dict))):
                for met_set in list(itertools.combinations(feature_dict.keys(), n_met+1)):
                    for n_met_set in range(len(met_set)):
                        if n_met_set == 0:
                            X = feature_dict[met_set[n_met_set]]
                        else:
                            X  = sparse.hstack((X,feature_dict[met_set[n_met_set]]), format='csr')
                    answer = run_model(X, outpatient['CLM_PMT_AMT'].values.tolist(), model, grid, met_set)
                    results[met_set] = answer

        else:
            X = None
            Name = ()
            for i in feature_list:
                if X == None:
                    X = feature_dict[i]
                    Name += (i,)
                else:
                    X = sparse.hstack((X, feature_dict[i]), format='csr')
                    Name += (i,)
            answer = run_model(X, outpatient['CLM_PMT_AMT'].values.tolist(), model, grid, feature_list)
            results[Name] = answer
        
    return results

# %%
def write_results(results_dict, filename):

    ### Takes in two arguements
    ### results_dict is the dictionary of feature sets
    ### file name is the wanted file name as a string

    ### Returns None, but writes a file to the current directory


    df = pd.DataFrame()

    for r_key in results_dict.keys():
        temp_df = results_dict[r_key]
        temp_df['features'] = str(r_key)
        df = pd.concat((df, temp_df), ignore_index=True)

    df.to_csv(filename)

    return None

# %% [markdown]
# # Final Histogram Gradient Boosted PCA Supervised Run
# ### See how the model performs on the dataset with PCA

# %%
grid_dict = {'learning_rate': [0.25],
    'max_iter': [200],
    #wanted to go a little higher on leaf nodes since there seemed to be more to gain
    'max_leaf_nodes': [10],
    'max_depth': [18]
    #results were inconclusive for minimum samples, going to leave as default
    }


GBRModel = HistGradientBoostingRegressor(random_state=42)
write_results(iterate_feature_sets(GBRModel, feature_dictionary, grid_dict, [
    # picked because of speed and results
    ['clm_dates', 'PCA-DGNS_CD', 'PCA-HCPCS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County'],
    ['clm_dates', 'PCA-HCPCS-DGNS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County']]), 'PCA_Final_GBRModel.csv')
# Out:
# {'mean_fit_time': array([810.20943007]), 'std_fit_time': array([231.51930883]), 'mean_score_time': array([9.08365698]), 'std_score_time': array([8.94627708]), 'param_learning_rate': masked_array(data=[0.25],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[18],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_iter': masked_array(data=[200],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_leaf_nodes': masked_array(data=[10],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'learning_rate': 0.25, 'max_depth': 18, 'max_iter': 200, 'max_leaf_nodes': 10}], 'split0_test_mean_squared_error': array([218156.09367574]), 'split1_test_mean_squared_error': array([217510.15012205]), 'split2_test_mean_squared_error': array([217644.2480655]), 'split3_test_mean_squared_error': array([223195.82319331]), 'split4_test_mean_squared_error': array([223922.86727122]), 'mean_test_mean_squared_error': array([220085.83646556]), 'std_test_mean_squared_error': array([2853.56773673]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([208010.0809651]), 'split1_train_mean_squared_error': array([209901.39388057]), 'split2_train_mean_squared_error': array([207860.75526166]), 'split3_train_mean_squared_error': array([206746.89586687]), 'split4_train_mean_squared_error': array([211858.64757947]), 'mean_train_mean_squared_error': array([208875.55471073]), 'std_train_mean_squared_error': array([1803.39902771]), 'split0_test_r2_score': array([0.31404523]), 'split1_test_r2_score': array([0.31705342]), 'split2_test_r2_score': array([0.32507529]), 'split3_test_r2_score': array([0.33410817]), 'split4_test_r2_score': array([0.33783035]), 'mean_test_r2_score': array([0.32562249]), 'std_test_r2_score': array([0.00926067]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.36697865]), 'split1_train_r2_score': array([0.36099791]), 'split2_train_r2_score': array([0.36529472]), 'split3_train_r2_score': array([0.36250381]), 'split4_train_r2_score': array([0.3452169]), 'mean_train_r2_score': array([0.3601984]), 'std_train_r2_score': array([0.00777616])}
# {'mean_fit_time': array([663.95124021]), 'std_fit_time': array([91.45697313]), 'mean_score_time': array([3.39509845]), 'std_score_time': array([0.5605073]), 'param_learning_rate': masked_array(data=[0.25],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[18],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_iter': masked_array(data=[200],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_leaf_nodes': masked_array(data=[10],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'learning_rate': 0.25, 'max_depth': 18, 'max_iter': 200, 'max_leaf_nodes': 10}], 'split0_test_mean_squared_error': array([220804.83238452]), 'split1_test_mean_squared_error': array([220328.63643219]), 'split2_test_mean_squared_error': array([220396.86158454]), 'split3_test_mean_squared_error': array([226195.19155297]), 'split4_test_mean_squared_error': array([226472.63807779]), 'mean_test_mean_squared_error': array([222839.6320064]), 'std_test_mean_squared_error': array([2859.0609855]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([211834.01674937]), 'split1_train_mean_squared_error': array([214170.60713865]), 'split2_train_mean_squared_error': array([214489.68899663]), 'split3_train_mean_squared_error': array([210047.08513736]), 'split4_train_mean_squared_error': array([210826.27004605]), 'mean_train_mean_squared_error': array([212273.53361361]), 'std_train_mean_squared_error': array([1775.1085807]), 'split0_test_r2_score': array([0.30571672]), 'split1_test_r2_score': array([0.30820383]), 'split2_test_r2_score': array([0.31653931]), 'split3_test_r2_score': array([0.32515973]), 'split4_test_r2_score': array([0.33029034]), 'mean_test_r2_score': array([0.31718199]), 'std_test_r2_score': array([0.00946516]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.35534155]), 'split1_train_r2_score': array([0.34800116]), 'split2_train_r2_score': array([0.34505319]), 'split3_train_r2_score': array([0.3523278]), 'split4_train_r2_score': array([0.34840763]), 'mean_train_r2_score': array([0.34982627]), 'std_train_r2_score': array([0.00360005])}

# %% [markdown]
# # Final Stochastic Gradient Descent PCA Supervised Run
# ### See how the model performs on the dataset with PCA

# %%
grid_dict = {'loss': ['squared_epsilon_insensitive'],
    'penalty': ['l1'],
    'alpha': [.0001],
    'max_iter': [1000]}

SGDModel = SGDRegressor(random_state=42)
write_results(iterate_feature_sets(SGDModel, feature_dictionary, grid_dict, [
    ['clm_dates', 'PCA-DGNS_CD', 'PCA-HCPCS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County'],
    ['clm_dates', 'PCA-HCPCS-DGNS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County']]), 'PCA_Final_SGDModel.csv')
# Out:
# {'mean_fit_time': array([2753.62727251]), 'std_fit_time': array([2342.89507068]), 'mean_score_time': array([30.0611599]), 'std_score_time': array([7.32015651]), 'param_alpha': masked_array(data=[0.0001],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_loss': masked_array(data=['squared_epsilon_insensitive'],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_max_iter': masked_array(data=[1000],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_penalty': masked_array(data=['l1'],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'alpha': 0.0001, 'loss': 'squared_epsilon_insensitive', 'max_iter': 1000, 'penalty': 'l1'}], 'split0_test_mean_squared_error': array([232241.33463155]), 'split1_test_mean_squared_error': array([233127.96589307]), 'split2_test_mean_squared_error': array([233732.24342608]), 'split3_test_mean_squared_error': array([239466.69041436]), 'split4_test_mean_squared_error': array([239495.35370293]), 'mean_test_mean_squared_error': array([235612.7176136]), 'std_test_mean_squared_error': array([3193.88061284]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([233651.52356088]), 'split1_train_mean_squared_error': array([233562.58889975]), 'split2_train_mean_squared_error': array([233338.4508498]), 'split3_train_mean_squared_error': array([232106.44423743]), 'split4_train_mean_squared_error': array([231888.94298087]), 'mean_train_mean_squared_error': array([232909.59010575]), 'std_train_mean_squared_error': array([754.65993055]), 'split0_test_r2_score': array([0.26975658]), 'split1_test_r2_score': array([0.26801601]), 'split2_test_r2_score': array([0.27518569]), 'split3_test_r2_score': array([0.28556498]), 'split4_test_r2_score': array([0.29178045]), 'mean_test_r2_score': array([0.27806074]), 'std_test_r2_score': array([0.00919419]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.28894598]), 'split1_train_r2_score': array([0.28896622]), 'split2_train_r2_score': array([0.28749827]), 'split3_train_r2_score': array([0.28430861]), 'split4_train_r2_score': array([0.28331007]), 'mean_train_r2_score': array([0.28660583]), 'std_train_r2_score': array([0.00236573])}

# %% [markdown]
# # Final Elastic Net NonPCA Supervised Run
# ### See how the model performs on the dataset without PCA

# %%
grid_dict = {'alpha': [.0001],
    'l1_ratio': [.9]}

ENModel = ElasticNet(random_state=42)
write_results(iterate_feature_sets(ENModel, feature_dictionary, grid_dict, [
    ['clm_dates', 'PCA-DGNS_CD', 'PCA-HCPCS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County'],
    ['clm_dates', 'PCA-HCPCS-DGNS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County']]), 'PCA_Final_ENModel.csv')
# Out:
# {'mean_fit_time': array([860.89285092]), 'std_fit_time': array([194.92109062]), 'mean_score_time': array([2.9623363]), 'std_score_time': array([0.94149851]), 'param_alpha': masked_array(data=[0.0001],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_l1_ratio': masked_array(data=[0.9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'alpha': 0.0001, 'l1_ratio': 0.9}], 'split0_test_mean_squared_error': array([234622.4237691]), 'split1_test_mean_squared_error': array([236443.48547151]), 'split2_test_mean_squared_error': array([237652.22084051]), 'split3_test_mean_squared_error': array([243252.95701962]), 'split4_test_mean_squared_error': array([242310.02897025]), 'mean_test_mean_squared_error': array([238856.2232142]), 'std_test_mean_squared_error': array([3360.2388376]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([238647.21062529]), 'split1_train_mean_squared_error': array([238196.91244482]), 'split2_train_mean_squared_error': array([237923.96550035]), 'split3_train_mean_squared_error': array([236505.88282103]), 'split4_train_mean_squared_error': array([236722.12654507]), 'mean_train_mean_squared_error': array([237599.21958731]), 'std_train_mean_squared_error': array([839.72130673]), 'split0_test_r2_score': array([0.26226965]), 'split1_test_r2_score': array([0.25760582]), 'split2_test_r2_score': array([0.26302966]), 'split3_test_r2_score': array([0.27426887]), 'split4_test_r2_score': array([0.28345708]), 'mean_test_r2_score': array([0.26812621]), 'std_test_r2_score': array([0.00942041]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.27374299]), 'split1_train_r2_score': array([0.27485796]), 'split2_train_r2_score': array([0.27349635]), 'split3_train_r2_score': array([0.27074311]), 'split4_train_r2_score': array([0.26837234]), 'mean_train_r2_score': array([0.27224255]), 'std_train_r2_score': array([0.0023618])}
# {'mean_fit_time': array([2959.72413712]), 'std_fit_time': array([1710.37357211]), 'mean_score_time': array([39.02220302]), 'std_score_time': array([37.08137833]), 'param_alpha': masked_array(data=[0.0001],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_l1_ratio': masked_array(data=[0.9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'alpha': 0.0001, 'l1_ratio': 0.9}], 'split0_test_mean_squared_error': array([235042.22666151]), 'split1_test_mean_squared_error': array([236884.75591149]), 'split2_test_mean_squared_error': array([238071.54174909]), 'split3_test_mean_squared_error': array([243637.66241208]), 'split4_test_mean_squared_error': array([242750.25205036]), 'mean_test_mean_squared_error': array([239277.28775691]), 'std_test_mean_squared_error': array([3352.25663294]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([239098.95999032]), 'split1_train_mean_squared_error': array([238636.31074052]), 'split2_train_mean_squared_error': array([238385.38076154]), 'split3_train_mean_squared_error': array([236964.99741184]), 'split4_train_mean_squared_error': array([237176.46014008]), 'mean_train_mean_squared_error': array([238052.42180886]), 'std_train_mean_squared_error': array([836.2811463]), 'split0_test_r2_score': array([0.26094965]), 'split1_test_r2_score': array([0.2562203]), 'split2_test_r2_score': array([0.26172932]), 'split3_test_r2_score': array([0.27312112]), 'split4_test_r2_score': array([0.28215528]), 'mean_test_r2_score': array([0.26683514]), 'std_test_r2_score': array([0.00946154]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.27236821]), 'split1_train_r2_score': array([0.27352031]), 'split2_train_r2_score': array([0.27208741]), 'split3_train_r2_score': array([0.26932745]), 'split4_train_r2_score': array([0.26696815]), 'mean_train_r2_score': array([0.2708543]), 'std_train_r2_score': array([0.00238132])}
# {'mean_fit_time': array([559.74512033]), 'std_fit_time': array([82.5145654]), 'mean_score_time': array([2.15237818]), 'std_score_time': array([1.35423895]), 'param_alpha': masked_array(data=[0.0001],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_l1_ratio': masked_array(data=[0.9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'alpha': 0.0001, 'l1_ratio': 0.9}], 'split0_test_mean_squared_error': array([235068.63983149]), 'split1_test_mean_squared_error': array([237066.82509709]), 'split2_test_mean_squared_error': array([238243.6539521]), 'split3_test_mean_squared_error': array([243876.80368135]), 'split4_test_mean_squared_error': array([242840.94042252]), 'mean_test_mean_squared_error': array([239419.37259691]), 'std_test_mean_squared_error': array([3388.84900592]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([239553.61505173]), 'split1_train_mean_squared_error': array([239046.73414837]), 'split2_train_mean_squared_error': array([238780.58596043]), 'split3_train_mean_squared_error': array([237360.44636949]), 'split4_train_mean_squared_error': array([237610.71884905]), 'mean_train_mean_squared_error': array([238470.42007581]), 'std_train_mean_squared_error': array([845.31413925]), 'split0_test_r2_score': array([0.2608666]), 'split1_test_r2_score': array([0.25564863]), 'split2_test_r2_score': array([0.2611956]), 'split3_test_r2_score': array([0.27240766]), 'split4_test_r2_score': array([0.2818871]), 'mean_test_r2_score': array([0.26640112]), 'std_test_r2_score': array([0.0094788]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.2709846]), 'split1_train_r2_score': array([0.27227085]), 'split2_train_r2_score': array([0.27088065]), 'split3_train_r2_score': array([0.26810809]), 'split4_train_r2_score': array([0.265626]), 'mean_train_r2_score': array([0.26957404]), 'std_train_r2_score': array([0.00239607])}

# %% [markdown]
# # Final CXGBoost NonPCA Supervised Run
# ### See how the model performs on the dataset without PCA

# %%
grid_dict = {'max_depth': [10],
    'number_of_estimators': [9],
    'tree_method': ['hist']}

XGBModel = xgb.XGBRFRegressor(random_state=42)
write_results(iterate_feature_sets(XGBModel, feature_dictionary, grid_dict, [
    ['clm_dates', 'PCA-DGNS_CD', 'PCA-HCPCS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County'],
    ['clm_dates', 'PCA-HCPCS-DGNS_CD', 'BIRTH_DATE', 'SEX', 'State', 'County']]), 'PCA_Final_XGBModel.csv')
# Out:
# {'mean_fit_time': array([201.49722433]), 'std_fit_time': array([31.13037309]), 'mean_score_time': array([1.62110672]), 'std_score_time': array([0.45685497]), 'param_max_depth': masked_array(data=[10],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_number_of_estimators': masked_array(data=[9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_tree_method': masked_array(data=['hist'],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'max_depth': 10, 'number_of_estimators': 9, 'tree_method': 'hist'}], 'split0_test_mean_squared_error': array([227138.4239546]), 'split1_test_mean_squared_error': array([226438.33402914]), 'split2_test_mean_squared_error': array([227835.52620283]), 'split3_test_mean_squared_error': array([232350.22450248]), 'split4_test_mean_squared_error': array([231112.14943849]), 'mean_test_mean_squared_error': array([228974.93162551]), 'std_test_mean_squared_error': array([2326.61275222]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([221125.41268437]), 'split1_train_mean_squared_error': array([221108.91600952]), 'split2_train_mean_squared_error': array([221184.97024594]), 'split3_train_mean_squared_error': array([219593.99942014]), 'split4_train_mean_squared_error': array([219741.59170223]), 'mean_train_mean_squared_error': array([220550.97801244]), 'std_train_mean_squared_error': array([723.06713082]), 'split0_test_r2_score': array([0.28580182]), 'split1_test_r2_score': array([0.28902037]), 'split2_test_r2_score': array([0.29347167]), 'split3_test_r2_score': array([0.30679654]), 'split4_test_r2_score': array([0.31657069]), 'mean_test_r2_score': array([0.29833222]), 'std_test_r2_score': array([0.01158994]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.32706575]), 'split1_train_r2_score': array([0.32687889]), 'split2_train_r2_score': array([0.32460907]), 'split3_train_r2_score': array([0.32289026]), 'split4_train_r2_score': array([0.3208534]), 'mean_train_r2_score': array([0.32445947]), 'std_train_r2_score': array([0.00237212])}
# {'mean_fit_time': array([289.76327944]), 'std_fit_time': array([60.75668587]), 'mean_score_time': array([1.76922584]), 'std_score_time': array([0.55471624]), 'param_max_depth': masked_array(data=[10],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_number_of_estimators': masked_array(data=[9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_tree_method': masked_array(data=['hist'],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'max_depth': 10, 'number_of_estimators': 9, 'tree_method': 'hist'}], 'split0_test_mean_squared_error': array([224407.09751285]), 'split1_test_mean_squared_error': array([224437.21775434]), 'split2_test_mean_squared_error': array([225378.05842028]), 'split3_test_mean_squared_error': array([230085.05398782]), 'split4_test_mean_squared_error': array([229782.14289618]), 'mean_test_mean_squared_error': array([226817.91411429]), 'std_test_mean_squared_error': array([2569.58329261]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([220958.68592081]), 'split1_train_mean_squared_error': array([221010.18998414]), 'split2_train_mean_squared_error': array([220114.10308456]), 'split3_train_mean_squared_error': array([219395.44391835]), 'split4_train_mean_squared_error': array([219679.7941753]), 'mean_train_mean_squared_error': array([220231.64341663]), 'std_train_mean_squared_error': array([656.09579733]), 'split0_test_r2_score': array([0.29439001]), 'split1_test_r2_score': array([0.29530355]), 'split2_test_r2_score': array([0.30109239]), 'split3_test_r2_score': array([0.31355455]), 'split4_test_r2_score': array([0.3205037]), 'mean_test_r2_score': array([0.30496884]), 'std_test_r2_score': array([0.01034797]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.32757314]), 'split1_train_r2_score': array([0.32717944]), 'split2_train_r2_score': array([0.32787897]), 'split3_train_r2_score': array([0.3235025]), 'split4_train_r2_score': array([0.3210444]), 'mean_train_r2_score': array([0.32543569]), 'std_train_r2_score': array([0.00270554])}
# {'mean_fit_time': array([198.93456445]), 'std_fit_time': array([53.55263042]), 'mean_score_time': array([1.40657606]), 'std_score_time': array([0.66557309]), 'param_max_depth': masked_array(data=[10],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_number_of_estimators': masked_array(data=[9],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'param_tree_method': masked_array(data=['hist'],
#              mask=[False],
#        fill_value='?',
#             dtype=object), 'params': [{'max_depth': 10, 'number_of_estimators': 9, 'tree_method': 'hist'}], 'split0_test_mean_squared_error': array([227738.03572915]), 'split1_test_mean_squared_error': array([227156.56814954]), 'split2_test_mean_squared_error': array([229546.20422062]), 'split3_test_mean_squared_error': array([235481.86589274]), 'split4_test_mean_squared_error': array([233677.55522372]), 'mean_test_mean_squared_error': array([230720.04584316]), 'std_test_mean_squared_error': array([3298.19507211]), 'rank_test_mean_squared_error': array([1]), 'split0_train_mean_squared_error': array([223644.15382896]), 'split1_train_mean_squared_error': array([222842.30663291]), 'split2_train_mean_squared_error': array([224543.41443484]), 'split3_train_mean_squared_error': array([223947.31957918]), 'split4_train_mean_squared_error': array([224360.4443122]), 'mean_train_mean_squared_error': array([223867.52775762]), 'std_train_mean_squared_error': array([601.1872473]), 'split0_test_r2_score': array([0.28391644]), 'split1_test_r2_score': array([0.28676523]), 'split2_test_r2_score': array([0.28816678]), 'split3_test_r2_score': array([0.29745347]), 'split4_test_r2_score': array([0.30898445]), 'mean_test_r2_score': array([0.29305727]), 'std_test_r2_score': array([0.00916584]), 'rank_test_r2_score': array([1]), 'split0_train_r2_score': array([0.31940066]), 'split1_train_r2_score': array([0.32160194]), 'split2_train_r2_score': array([0.31435402]), 'split3_train_r2_score': array([0.30946696]), 'split4_train_r2_score': array([0.3065781]), 'mean_train_r2_score': array([0.31428033]), 'std_train_r2_score': array([0.00569775])}
